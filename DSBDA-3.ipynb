# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Customers.csv")

# %%
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# 0        Healthcare                1            4
# 1          Engineer                3            3
# 2          Engineer                1            1
# 3            Lawyer                0            2
# 4     Entertainment                2            6
# ...             ...              ...          ...
# 1995         Artist                8            7
# 1996         Doctor                7            7
# 1997     Healthcare                9            2
# 1998      Executive                7            2
# 1999  Entertainment                5            2
#
# [2000 rows x 8 columns]

# %%
df.mean()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16352\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# CustomerID                  1000.5000
# Age                           48.9600
# Annual Income ($)         110731.8215
# Spending Score (1-100)        50.9625
# Work Experience                4.1025
# Family Size                    3.7685
# dtype: float64

# %%
df.loc[:,'Age'].mean()
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# 0        Healthcare                1            4
# 1          Engineer                3            3
# 2          Engineer                1            1
# 3            Lawyer                0            2
# 4     Entertainment                2            6
# ...             ...              ...          ...
# 1995         Artist                8            7
# 1996         Doctor                7            7
# 1997     Healthcare                9            2
# 1998      Executive                7            2
# 1999  Entertainment                5            2
#
# [2000 rows x 8 columns]

# %%
df.mean(axis=1)[0:4]
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16352\1148177455.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis=1)[0:4]
# 0     2510.666667
# 1     5851.666667
# 2    14338.500000
# 3     9851.000000
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16352\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# CustomerID                  1000.5
# Age                           48.0
# Annual Income ($)         110045.0
# Spending Score (1-100)        50.0
# Work Experience                3.0
# Family Size                    4.0
# dtype: float64

# %%
df.loc[:, 'Age'].median()
# Out:
# 48.0

# %%
df.median(axis=1)[0:4]
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16352\381455229.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median(axis=1)[0:4]
# 0    11.5
# 1    12.0
# 2     4.5
# 3    13.5
# dtype: float64

# %%
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# 0        Healthcare                1            4
# 1          Engineer                3            3
# 2          Engineer                1            1
# 3            Lawyer                0            2
# 4     Entertainment                2            6
# ...             ...              ...          ...
# 1995         Artist                8            7
# 1996         Doctor                7            7
# 1997     Healthcare                9            2
# 1998      Executive                7            2
# 1999  Entertainment                5            2
#
# [2000 rows x 8 columns]

# %%
df.mode()
# Out:
#       CustomerID  Gender   Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1  Female  31.0             9000.0                    49.0
# 1              2     NaN   NaN            50000.0                     NaN
# 2              3     NaN   NaN                NaN                     NaN
# 3              4     NaN   NaN                NaN                     NaN
# 4              5     NaN   NaN                NaN                     NaN
# ...          ...     ...   ...                ...                     ...
# 1995        1996     NaN   NaN                NaN                     NaN
# 1996        1997     NaN   NaN                NaN                     NaN
# 1997        1998     NaN   NaN                NaN                     NaN
# 1998        1999     NaN   NaN                NaN                     NaN
# 1999        2000     NaN   NaN                NaN                     NaN
#
#      Profession  Work Experience  Family Size
# 0        Artist              1.0          2.0
# 1           NaN              NaN          NaN
# 2           NaN              NaN          NaN
# 3           NaN              NaN          NaN
# 4           NaN              NaN          NaN
# ...         ...              ...          ...
# 1995        NaN              NaN          NaN
# 1996        NaN              NaN          NaN
# 1997        NaN              NaN          NaN
# 1998        NaN              NaN          NaN
# 1999        NaN              NaN          NaN
#
# [2000 rows x 8 columns]

# %%
df.loc[:, 'Age'].mode()
# Out:
# 0    31
# Name: Age, dtype: int64

# %%
df.min()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16352\3962516015.py:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.min()
# CustomerID                     1
# Gender                    Female
# Age                            0
# Annual Income ($)              0
# Spending Score (1-100)         0
# Work Experience                0
# Family Size                    1
# dtype: object

# %%
df.loc[:, 'Age'].min(skipna=False)
# Out:
# 0

# %%
df.max()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16352\1151452817.py:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.max()
# CustomerID                  2000
# Gender                      Male
# Age                           99
# Annual Income ($)         189974
# Spending Score (1-100)       100
# Work Experience               17
# Family Size                    9
# dtype: object

# %%
df.std()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16352\3390915376.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# CustomerID                  577.494589
# Age                          28.429747
# Annual Income ($)         45739.536688
# Spending Score (1-100)       27.934661
# Work Experience               3.922204
# Family Size                   1.970749
# dtype: float64

# %%
df.std(axis=1)[0:4]
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16352\3966588610.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std(axis=1)[0:4]
# 0     6118.516443
# 1    14279.740945
# 2    35106.822566
# 3    24078.011845
# dtype: float64

# %%
df.groupby(['CustomerID'])['Age'].mean()
# Out:
# CustomerID
# 1       19.0
# 2       21.0
# 3       20.0
# 4       23.0
# 5       31.0
#         ...
# 1996    71.0
# 1997    91.0
# 1998    87.0
# 1999    77.0
# 2000    90.0
# Name: Age, Length: 2000, dtype: float64

# %%
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# 0        Healthcare                1            4
# 1          Engineer                3            3
# 2          Engineer                1            1
# 3            Lawyer                0            2
# 4     Entertainment                2            6
# ...             ...              ...          ...
# 1995         Artist                8            7
# 1996         Doctor                7            7
# 1997     Healthcare                9            2
# 1998      Executive                7            2
# 1999  Entertainment                5            2
#
# [2000 rows x 8 columns]

# %%
data = pd.read_csv('IRIS.csv')

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
print('SepalLengthCm')
# Out:
# SepalLengthCm

# %%
print(data[IRISSet].describe())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 print(data[IRISSet].describe())
#
# NameError: name 'IRISSet' is not defined
